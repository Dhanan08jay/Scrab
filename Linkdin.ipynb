# %%
import pandas as pd
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
s = Service(ChromeDriverManager().install())
browser = webdriver.Chrome(service=s)
browser.maximize_window()
browser.get('https://www.linkedin.com')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\lenovo\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache

# %%
username = browser.find_element_by_id("session_key")
username.send_keys("Your email id")
password = browser.find_element_by_id("session_password")
password.send_keys("Your linkedin password")
# Out:
# <ipython-input-3-bb6deed6f56f>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username = browser.find_element_by_id("session_key")
# <ipython-input-3-bb6deed6f56f>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password = browser.find_element_by_id("session_password")

# %%
login_button = username = browser.find_element_by_class_name("sign-in-form__submit-button")
login_button.click()
# Out:
# <ipython-input-4-0ec88bc97886>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   login_button = username = browser.find_element_by_class_name("sign-in-form__submit-button")

# %%
browser.get('https://www.linkedin.com/jobs/')

# %%
job_title_extract = browser.find_elements_by_class_name("job-card-list__title")
job_title = []
for i in job_title_extract:
    job_title.append(i.text)
print(job_title)
print()
print(len(job_title))
# Out:
# <ipython-input-23-0c72426b5ab3>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   job_title_extract = browser.find_elements_by_class_name("job-card-list__title")
# ['Quality Analyst', 'WEB DEVELOPMENT STUDENT INTERN', 'Software Engineering - Python Developer', 'Application Analyst-Technology', 'Software Engineer Intern', 'Computer Science Intern', 'ReactJS Developer', 'Student', 'HTML Developer', 'CS Reporting and Backoffice Support', 'Project Manager', 'Junior Project Manager Intern (Remote Internship)', 'Software Development Engineer I', 'Sr/Jr Java Developer', 'Junior Developer - Java, Upland (Remote) - $30,000/year USD', 'Intern', 'Application Developer: Java & Web Technologies', 'Software Developer', 'Computer Science Intern', 'Student Intern', 'ReactJS Developer', 'HTML Developer', 'Engineering Associate']
#
# 23

# %%
company_name_extract = browser.find_elements_by_class_name("artdeco-entity-lockup__subtitle")
company_name = []
for i in company_name_extract:
    company_name.append(i.text)
print(company_name)
print()
print(len(company_name))
# Out:
# <ipython-input-25-7aef36b593fe>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   company_name_extract = browser.find_elements_by_class_name("artdeco-entity-lockup__subtitle")
# ['Tata Consultancy Services', 'SkillVertex', 'JPMorgan Chase & Co.', 'Wipro', 'privado.ai', 'Mach Infinity', 'Infosys', 'ONLINE WORK FROM HOME OPPORTUNITY', 'Aptimized', 'Hotstar', 'Tata Elxsi', 'Brainnest', 'Amazon', 'Capita', 'Crossover for Work', 'VidyaInfinity Foundation', 'IBM', 'Tata Institute of Social Sciences', 'Mach Infinity', 'Mastergy', 'Infosys', 'Aptimized', 'Marriott Hotels']
#
# 23

# %%
company_location_extract = browser.find_elements_by_class_name("job-card-container__metadata-item")
company_location = []
for i in company_location_extract:
    company_location.append(i.text)
print(company_location)
print()
print(len(company_location))
# Out:
# <ipython-input-26-c179e156fbe7>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   company_location_extract = browser.find_elements_by_class_name("job-card-container__metadata-item")
# ['Mumbai, Maharashtra, India (Hybrid)', 'Bengaluru, Karnataka, India (Remote)', 'Mumbai, Maharashtra, India', 'Mumbai, Maharashtra, India (On-site)', 'Pune, Maharashtra, India (Remote)', 'Karnataka, India (Remote)', 'India (Remote)', 'India (Remote)', 'Hyderabad, Telangana, India (Remote)', 'Mumbai, Maharashtra, India', 'Mumbai, Maharashtra, India (On-site)', 'Mumbai, Maharashtra, India (On-site)', 'Mumbai, Maharashtra, India (On-site)', 'Pune, Maharashtra, India (Remote)', 'Mumbai, Maharashtra, India (Remote)', 'Mumbai, Maharashtra, India (Hybrid)', 'Mumbai, Maharashtra, India (On-site)', 'Mumbai, Maharashtra, India (On-site)', 'Karnataka, India (Remote)', 'India (Remote)', 'India (Remote)', 'Hyderabad, Telangana, India (Remote)', 'Mumbai, Maharashtra, India (On-site)']
#
# 23

# %%
column = ["Company Name","Job Title","Location"]
df = pd.DataFrame({"Company Name" : company_name , "Job Title" : job_title , "Company Location" : company_location})

# %%
df.head()
# Out:
#                 Company Name                                Job Title  \
# 0  Tata Consultancy Services                          Quality Analyst
# 1                SkillVertex           WEB DEVELOPMENT STUDENT INTERN
# 2       JPMorgan Chase & Co.  Software Engineering - Python Developer
# 3                      Wipro           Application Analyst-Technology
# 4                 privado.ai                 Software Engineer Intern
#
#                        Company Location
# 0   Mumbai, Maharashtra, India (Hybrid)
# 1  Bengaluru, Karnataka, India (Remote)
# 2            Mumbai, Maharashtra, India
# 3  Mumbai, Maharashtra, India (On-site)
# 4     Pune, Maharashtra, India (Remote)

# %%
df.to_csv("linkedin_scrapejobs.csv")
